# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

x = [400, 800, 1200, 1600, 2000]

y00=[76.026, 692.939, 1668.44, 4175.65, 8424.81]
y01=[40.7, 387.572, 828.266, 2144.52, 4393.6]

y10=[0.684, 2.788, 4.336, 8.305, 12.888]
y11=[0.677, 2.968, 5.838, 11.573, 21.022]


fig = plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  

plt.title("LU and LDLT")
plt.plot(x, y00, label="LU")
plt.plot(x, y01, label="LDLT")

plt.legend()

plt.subplot(1, 2, 2)  

plt.title("Solution")
plt.plot(x, y10, label="LU")
plt.plot(x, y11, label="LDLT")

plt.legend()

plt.show()
