# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

x = [0, 50, 90, 95, 99]

y0=[5952.76, 5929.43, 5775.17, 5053.22, 4933.14]
y1=[13237, 13778, 14150.9, 13747.5, 14663.6]
y2=[23441.6, 15482.6, 9074.73, 9147.18, 7773.34]


fig = plt.figure(figsize=(10, 5))

plt.title("Gauss & GMRES")
plt.plot(x, y0, label="Gauss")
plt.plot(x, y1, label="GMRES")
plt.plot(x, y2, label="GMRES optimized 1")

plt.legend()

plt.show()
