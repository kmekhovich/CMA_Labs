# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

x = [0, 50, 90, 95, 99]

y0=[738.379, 347.195, 377.51, 343.774, 431.992]
y1=[4882.82, 4078.79, 4822.14, 4938.19, 4308.4]
y2=[4823.84, 2828.75, 1725.06, 1526.59, 872.71]



fig = plt.figure(figsize=(10, 5))

plt.title("Gauss & GMRES")
plt.plot(x, y0, label="Gauss")
plt.plot(x, y1, label="GMRES")
plt.plot(x, y2, label="GMRES optimized 1")

plt.legend()

plt.show()
