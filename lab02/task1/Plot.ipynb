# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

x = [25, 75, 150, 250, 500, 1000]
y0 = [4.34567, 51.805, 181.531, 425.983, 3134.45, 17462.6]
y1 = [367, 744, 952, 976, 2110, 2930]


fig = plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  

plt.title("Time")
plt.plot(x, y0)


plt.subplot(1, 2, 2)  

plt.title("Iterations")
plt.plot(x, y1)

plt.show()
