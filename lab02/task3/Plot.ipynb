# %%
from matplotlib import pyplot as plt
import numpy as np
# %matplotlib inline

x = [25, 75, 150, 250]
y00 = [0.034, 0.609, 5.091, 29.013]
y01 = [2.91, 11152, 35494.5, 349430]
y1 = [1094, 172676, 177057, 458130]


fig = plt.figure(figsize=(10, 5))

plt.subplot(1, 2, 1)  

plt.title("Time")
plt.plot(x, y00, label="make hessen")
plt.plot(x, y01, label="qr algo")
plt.legend()

plt.subplot(1, 2, 2)  

plt.title("Iterations")
plt.plot(x, y1)

plt.show()
